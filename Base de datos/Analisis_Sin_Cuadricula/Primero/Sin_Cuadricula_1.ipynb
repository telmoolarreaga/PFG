# %% [markdown]
# # 1. Data Processing

# %% [markdown]
# ###  Load dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler, StandardScaler

# %%
df = pd.read_csv('C:\\Users\\Usuario\\Documents\\GitHub\\PFG\\Analizador\\pollution-particle-analyzer-main\\output\\particle_features_sin_cuadricula.csv')

# %% [markdown]
# ### View columns

# %%
print("\n Columns:", df.columns.tolist())
# Out:
#  Columns: ['image_name', 'area', 'perimeter', 'major_axis', 'minor_axis', 'aspect_ratio', 'eccentricity', 'equivalent_diameter', 'feret_max', 'feret_min', 'solidity', 'extent', 'convex_area', 'compactness', 'roundness', 'sphericity', 'rectangularity', 'convex_ratio', 'area_perimeter_ratio', 'mean_intensity', 'std_intensity', 'intensity_range', 'contrast_internal', 'intensity_entropy', 'local_variance', 'glcm_contrast', 'glcm_homogeneity', 'glcm_energy', 'glcm_correlation', 'lbp_mean', 'lbp_std', 'hu1', 'hu2', 'hu3', 'hu4', 'hu5', 'hu6', 'hu7', 'fractal_dimension', 'convexity_defects', 'hull_ratio', 'roughness_index', 'euler_number', 'holes']

# %% [markdown]
# ### General information of the dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292992 entries, 0 to 292991
# Data columns (total 44 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   image_name            292992 non-null  object
#  1   area                  292992 non-null  float64
#  2   perimeter             292992 non-null  float64
#  3   major_axis            292992 non-null  float64
#  4   minor_axis            292992 non-null  float64
#  5   aspect_ratio          292992 non-null  float64
#  6   eccentricity          292992 non-null  float64
#  7   equivalent_diameter   292992 non-null  float64
#  8   feret_max             292992 non-null  float64
#  9   feret_min             292992 non-null  float64
#  10  solidity              292992 non-null  float64
#  11  extent                292992 non-null  float64
#  12  convex_area           292992 non-null  float64
#  13  compactness           292992 non-null  float64
#  14  roundness             292992 non-null  float64
#  15  sphericity            292992 non-null  float64
#  16  rectangularity        292992 non-null  float64
#  17  convex_ratio          292992 non-null  float64
#  18  area_perimeter_ratio  292992 non-null  float64
#  19  mean_intensity        292992 non-null  float64
#  20  std_intensity         292992 non-null  float64
#  21  intensity_range       292992 non-null  int64
#  22  contrast_internal     292992 non-null  float64
#  23  intensity_entropy     292992 non-null  float64
#  24  local_variance        292992 non-null  float64
#  25  glcm_contrast         292992 non-null  float64
#  26  glcm_homogeneity      292992 non-null  float64
#  27  glcm_energy           292992 non-null  float64
#  28  glcm_correlation      292992 non-null  float64
#  29  lbp_mean              292992 non-null  float64
#  30  lbp_std               292992 non-null  float64
#  31  hu1                   292992 non-null  float64
#  32  hu2                   292992 non-null  float64
#  33  hu3                   292992 non-null  float64
#  34  hu4                   292992 non-null  float64
#  35  hu5                   292992 non-null  float64
#  36  hu6                   292992 non-null  float64
#  37  hu7                   292992 non-null  float64
#  38  fractal_dimension     292992 non-null  float64
#  39  convexity_defects     292992 non-null  float64
#  40  hull_ratio            292992 non-null  float64
#  41  roughness_index       292992 non-null  float64
#  42  euler_number          292992 non-null  int64
#  43  holes                 292992 non-null  int64
# dtypes: float64(40), int64(3), object(1)
# memory usage: 98.4+ MB
# None

# %% [markdown]
# ### Numerical statistics

# %%
display(df.describe(include=[int, float]))
# Out:
#                 area      perimeter     major_axis     minor_axis  \
# count  292992.000000  292992.000000  292992.000000  292992.000000
# mean       36.981556      22.812081       9.651195       5.249283
# std        50.966992      20.130454       5.892766       2.874466
# min        12.000000       4.242641       3.829708       0.000000
# 25%        16.000000      13.035534       6.292925       3.672238
# 50%        23.000000      17.071068       8.063804       4.525079
# 75%        39.000000      25.313708      10.958131       5.958101
# max      1193.000000     671.008189     124.298094      70.255884
#
#         aspect_ratio   eccentricity  equivalent_diameter      feret_max  \
# count  292992.000000  292992.000000        292992.000000  292992.000000
# mean        1.907235       0.772789             6.258751       9.723804
# std         0.691705       0.158612             2.813263       5.637693
# min         1.000000       0.000000             3.908820       4.123106
# 25%         1.366260       0.681502             4.513517       6.324555
# 50%         1.706724       0.810370             5.411516       8.062258
# 75%         2.288933       0.899591             7.046726      11.045361
# max         4.000000       1.000000            38.974027      98.979796
#
#            feret_min       solidity  ...            hu4           hu5  \
# count  292992.000000  292992.000000  ...  292992.000000  2.929920e+05
# mean        5.249283       0.792241  ...       0.001326  4.040012e-05
# std         2.874466       0.140276  ...       0.005694  1.287601e-03
# min         0.000000       0.300000  ...       0.000000 -1.219286e-02
# 25%         3.672238       0.695652  ...       0.000012 -1.790107e-11
# 50%         4.525079       0.814815  ...       0.000095  1.714338e-09
# 75%         5.958101       0.909091  ...       0.000649  3.079880e-07
# max        70.255884       1.000000  ...       0.519351  3.380704e-01
#
#                 hu6           hu7  fractal_dimension  convexity_defects  \
# count  2.929920e+05  2.929920e+05      292992.000000      292992.000000
# mean   2.839677e-04  4.603065e-07           0.904669           6.438179
# std    2.788134e-03  5.136644e-04           0.050635          43.613844
# min   -7.168574e-02 -1.080266e-01           0.578892           0.000000
# 25%   -1.297694e-07 -1.016556e-08           0.872422           0.000000
# 50%    7.338120e-07  0.000000e+00           0.907606           0.000000
# 75%    3.677194e-05  1.114744e-08           0.937381           0.000000
# max    3.282348e-01  7.453284e-02           1.098129        2274.500000
#
#           hull_ratio  roughness_index   euler_number          holes
# count  292992.000000    292992.000000  292992.000000  292992.000000
# mean        1.212192         1.071422       0.486297       0.513703
# std         0.300931         0.266567       1.169868       1.169868
# min         0.000000         0.345364     -44.000000       0.000000
# 25%         1.000000         0.908049       0.000000       0.000000
# 50%         1.219512         1.002054       1.000000       0.000000
# 75%         1.419355         1.155739       1.000000       1.000000
# max         2.400000         5.648498       1.000000      45.000000
#
# [8 rows x 43 columns]

# %% [markdown]
# ### Null values

# %%
print("\n Null values per column:")
print(df.isna().sum())
# Out:
#  Null values per column:
# image_name              0
# area                    0
# perimeter               0
# major_axis              0
# minor_axis              0
# aspect_ratio            0
# eccentricity            0
# equivalent_diameter     0
# feret_max               0
# feret_min               0
# solidity                0
# extent                  0
# convex_area             0
# compactness             0
# roundness               0
# sphericity              0
# rectangularity          0
# convex_ratio            0
# area_perimeter_ratio    0
# mean_intensity          0
# std_intensity           0
# intensity_range         0
# contrast_internal       0
# intensity_entropy       0
# local_variance          0
# glcm_contrast           0
# glcm_homogeneity        0
# glcm_energy             0
# glcm_correlation        0
# lbp_mean                0
# lbp_std                 0
# hu1                     0
# hu2                     0
# hu3                     0
# hu4                     0
# hu5                     0
# hu6                     0
# hu7                     0
# fractal_dimension       0
# convexity_defects       0
# hull_ratio              0
# roughness_index         0
# euler_number            0
# holes                   0
# dtype: int64

# %% [markdown]
# ### Infinite values

# %%
features = df.drop(columns=["image_name"], errors="ignore")
inf_rows = np.isinf(features).any(axis=1).sum()
print(f"Rows with inf o -inf: {inf_rows} de {len(features)}")
# Out:
# Rows with inf o -inf: 0 de 292992

# %%
features = df.drop(columns=["image_name"], errors="ignore")
inf_counts = np.isinf(features).sum()
print("Inf values per column:")
print(inf_counts[inf_counts > 0].sort_values(ascending=False))
# Out:
# Inf values per column:
# Series([], dtype: int64)

# %% [markdown]
# ### Variables correlation

# %%
# Numerical Columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

#  Correlation matrix
corr_matrix = numeric_df.corr()

#  Highly correlated pairs
threshold = 0.9
high_corr = (corr_matrix.abs() > threshold) & (corr_matrix.abs() < 1.0)  
print("Variables highly correlated (> 0.9):")
for col in high_corr.columns:
    correlated_cols = high_corr.index[high_corr[col]].tolist()
    if correlated_cols:
        print(f"{col} ↔ {correlated_cols}")

# Correlation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# Variables highly correlated (> 0.9):
# area ↔ ['perimeter', 'equivalent_diameter', 'convex_area']
# perimeter ↔ ['area', 'major_axis', 'equivalent_diameter', 'feret_max', 'convex_area', 'compactness']
# major_axis ↔ ['perimeter', 'feret_max']
# minor_axis ↔ ['equivalent_diameter']
# equivalent_diameter ↔ ['area', 'perimeter', 'minor_axis', 'feret_max', 'feret_min']
# feret_max ↔ ['perimeter', 'major_axis', 'equivalent_diameter']
# feret_min ↔ ['equivalent_diameter']
# solidity ↔ ['rectangularity']
# convex_area ↔ ['area', 'perimeter', 'convexity_defects']
# compactness ↔ ['perimeter', 'roughness_index']
# rectangularity ↔ ['solidity', 'convex_ratio']
# convex_ratio ↔ ['rectangularity']
# std_intensity ↔ ['intensity_range', 'contrast_internal', 'local_variance']
# intensity_range ↔ ['std_intensity', 'contrast_internal', 'local_variance']
# contrast_internal ↔ ['std_intensity', 'intensity_range']
# local_variance ↔ ['std_intensity', 'intensity_range']
# convexity_defects ↔ ['convex_area']
# roughness_index ↔ ['compactness']
# euler_number ↔ ['holes']
# holes ↔ ['euler_number']

# %% [markdown]
#  Correlation Matrix — Updated Dataset
#
# After correcting the feature extractor (fixing `convexity_defects`,
# `hull_ratio`, and `fractal_dimension`), the correlation matrix reveals
# some new relationships that were previously hidden by numerical artefacts:
#
# - **`roundness` ↔ `fractal_dimension`** (>0.9) — now that `fractal_dimension`
#   returns `NaN` instead of 0 for invalid cases, its real distribution emerges
#   and shows a strong mathematical relationship with `roundness`, as both
#   depend on the perimeter/area ratio.
# - **`compactness` ↔ `roughness_index`** (>0.9) — a new redundancy detected,
#   as both capture contour irregularity through similar geometric formulas.
# - **`area_perimeter_ratio`** now correlates strongly with `roundness`,
#   `sphericity` and `fractal_dimension`, forming a block of redundant
#   shape descriptors.
#
# The core structure remains unchanged: the size block (`area`, `perimeter`,
# `equivalent_diameter`, `feret_max`, `convex_area`), the intensity block
# (`std_intensity`, `intensity_range`, `local_variance`) and the Hu moments
# block maintain the same correlations as before.
#
# These new redundancies do not affect the clustering variable selection,
# as `fractal_dimension`, `area_perimeter_ratio` and `roughness_index`
# are not part of `columnas_clustering`.

# %% [markdown]
# ### Data reduction

# %%
# Columns for clustering
columns_clustering = [
    # Size
    "perimeter",
    "equivalent_diameter",

    # Form
    "roundness",        
    "aspect_ratio",
    "compactness",
    "solidity",

    # Intensity / texture
    "mean_intensity",
    "std_intensity",
    "intensity_entropy",
    "glcm_energy",
    "glcm_correlation",
    "lbp_mean",

    # Invariant moments
    "hu1",
    "hu2",
    "hu4",
    "hu7",

    # Topology / morphology
    "euler_number",
    "holes",
    "convexity_defects"
]

df_clustering = df[columns_clustering].copy()
print("Columns for clustering:")
print(df_clustering.columns)
print("\nFirst rows of the dataset:")
print(df_clustering.head())
# Out:
# Columns for clustering:
# Index(['perimeter', 'equivalent_diameter', 'roundness', 'aspect_ratio',
#        'compactness', 'solidity', 'mean_intensity', 'std_intensity',
#        'intensity_entropy', 'glcm_energy', 'glcm_correlation', 'lbp_mean',
#        'hu1', 'hu2', 'hu4', 'hu7', 'euler_number', 'holes',
#        'convexity_defects'],
#       dtype='object')
#
# First rows of the dataset:
#    perimeter  equivalent_diameter  roundness  aspect_ratio  compactness  \
# 0  10.449747             4.068429   1.496035      1.546418     8.399786
# 1  22.727922             7.399277   1.046065      1.297407    12.012987
# 2  39.556349             9.836982   0.610367      2.441350    20.588221
# 3  23.071068             7.569398   1.062397      1.177620    11.828315
# 4  28.142136             8.136858   0.825086      2.152002    15.230381
#
#    solidity  mean_intensity  std_intensity  intensity_entropy  glcm_energy  \
# 0  0.866667      153.615385       9.186432           3.382922     0.182574
# 1  0.914894      115.976744      32.312780           3.343532     0.096225
# 2  0.775510      129.118421      15.756341           3.365378     0.063324
# 3  0.918367      118.511111      27.181384           3.338377     0.105203
# 4  0.896552      113.096154      33.979213           3.341955     0.088932
#
#    glcm_correlation    lbp_mean       hu1       hu2           hu4  \
# 0          0.131700   86.450000  0.182066  0.005580  7.912208e-05
# 1          0.796091  108.888889  0.165268  0.001771  1.564581e-06
# 2          0.887203  109.814103  0.277587  0.039134  1.136710e-04
# 3          0.727220  105.142857  0.162809  0.000696  1.050553e-07
# 4          0.826634  115.369048  0.217733  0.019712  6.337385e-05
#
#             hu7  euler_number  holes  convexity_defects
# 0  1.688464e-08             1      0                0.0
# 1 -3.462686e-12             1      0                0.0
# 2  2.342004e-08             1      0                5.0
# 3 -3.365761e-13             1      0                0.0
# 4  1.991605e-09             1      0                0.0

# %% [markdown]
# ### Null values

# %%
print("\n Null values by column:")
print(df_clustering.isna().sum())
# Out:
#  Null values by column:
# perimeter              0
# equivalent_diameter    0
# roundness              0
# aspect_ratio           0
# compactness            0
# solidity               0
# mean_intensity         0
# std_intensity          0
# intensity_entropy      0
# glcm_energy            0
# glcm_correlation       0
# lbp_mean               0
# hu1                    0
# hu2                    0
# hu4                    0
# hu7                    0
# euler_number           0
# holes                  0
# convexity_defects      0
# dtype: int64

# %% [markdown]
# ### Noisy data

# %%
for col in df_clustering.columns:
    print(f"\n🔹 {col}")
    print(df_clustering[col].describe(percentiles=[0.01, 0.99]))
    
    plt.figure(figsize=(6,3))
    plt.boxplot(df_clustering[col])
    plt.title(f"Boxplot of {col}")
    plt.show()
# Out:
# 🔹 perimeter
# count    292992.000000
# mean         22.812081
# std          20.130454
# min           4.242641
# 1%            9.242641
# 50%          17.071068
# 99%          96.633514
# max         671.008189
# Name: perimeter, dtype: float64
# 🔹 equivalent_diameter
# count    292992.000000
# mean          6.258751
# std           2.813263
# min           3.908820
# 1%            3.908820
# 50%           5.411516
# 99%          17.149879
# max          38.974027
# Name: equivalent_diameter, dtype: float64
# 🔹 roundness
# count    292992.000000
# mean          0.987954
# std           0.360426
# min           0.031343
# 1%            0.236862
# 50%           0.995905
# 99%           1.934748
# max           8.383909
# Name: roundness, dtype: float64
# 🔹 aspect_ratio
# count    292992.000000
# mean          1.907235
# std           0.691705
# min           1.000000
# 1%            1.045456
# 50%           1.706724
# 99%           3.846688
# max           4.000000
# Name: aspect_ratio, dtype: float64
# 🔹 compactness
# count    292992.000000
# mean         15.318440
# std           9.951053
# min           1.498868
# 1%            6.495094
# 50%          12.618046
# 99%          53.053657
# max         400.936767
# Name: compactness, dtype: float64
# 🔹 solidity
# count    292992.000000
# mean          0.792241
# std           0.140276
# min           0.300000
# 1%            0.439024
# 50%           0.814815
# 99%           1.000000
# max           1.000000
# Name: solidity, dtype: float64
# 🔹 mean_intensity
# count    292992.000000
# mean        132.389948
# std          27.637016
# min           1.774194
# 1%           53.413317
# 50%         135.428571
# 99%         189.059529
# max         241.633333
# Name: mean_intensity, dtype: float64
# 🔹 std_intensity
# count    292992.000000
# mean          7.501902
# std           7.878550
# min           0.000000
# 1%            0.493007
# 50%           4.409456
# 99%          35.295522
# max          55.540956
# Name: std_intensity, dtype: float64
# 🔹 intensity_entropy
# count    292992.000000
# mean          3.244220
# std           0.168349
# min           1.512397
# 1%            2.594576
# 50%           3.306441
# 99%           3.397524
# max           3.431487
# Name: intensity_entropy, dtype: float64
# 🔹 glcm_energy
# count    292992.000000
# mean          0.161033
# std           0.075963
# min           0.000000
# 1%            0.043517
# 50%           0.150231
# 99%           0.437500
# max           1.000000
# Name: glcm_energy, dtype: float64
# 🔹 glcm_correlation
# count    292992.000000
# mean          0.675385
# std           0.215347
# min          -0.927130
# 1%           -0.013091
# 50%           0.721743
# 99%           0.966480
# max           1.000000
# Name: glcm_correlation, dtype: float64
# 🔹 lbp_mean
# count    292992.000000
# mean        101.811512
# std          18.431741
# min           7.166667
# 1%           60.062500
# 50%         101.452381
# 99%         148.392424
# max         203.503205
# Name: lbp_mean, dtype: float64
# 🔹 hu1
# count    292992.000000
# mean          0.252088
# std           0.103163
# min           0.152778
# 1%            0.157475
# 50%           0.216975
# 99%           0.606149
# max           4.081633
# Name: hu1, dtype: float64
# 🔹 hu2
# count    292992.000000
# mean          0.031705
# std           0.089583
# min           0.000000
# 1%            0.000062
# 50%           0.011189
# 99%           0.240962
# max          16.659725
# Name: hu2, dtype: float64
# 🔹 hu4
# count    292992.000000
# mean          0.001326
# std           0.005694
# min           0.000000
# 1%            0.000000
# 50%           0.000095
# 99%           0.020508
# max           0.519351
# Name: hu4, dtype: float64
# 🔹 hu7
# count    2.929920e+05
# mean     4.603065e-07
# std      5.136644e-04
# min     -1.080266e-01
# 1%      -7.786980e-05
# 50%      0.000000e+00
# 99%      7.827829e-05
# max      7.453284e-02
# Name: hu7, dtype: float64
# 🔹 euler_number
# count    292992.000000
# mean          0.486297
# std           1.169868
# min         -44.000000
# 1%           -4.000000
# 50%           1.000000
# 99%           1.000000
# max           1.000000
# Name: euler_number, dtype: float64
# 🔹 holes
# count    292992.000000
# mean          0.513703
# std           1.169868
# min           0.000000
# 1%            0.000000
# 50%           0.000000
# 99%           5.000000
# max          45.000000
# Name: holes, dtype: float64
# 🔹 convexity_defects
# count    292992.000000
# mean          6.438179
# std          43.613844
# min           0.000000
# 1%            0.000000
# 50%           0.000000
# 99%         111.545000
# max        2274.500000
# Name: convexity_defects, dtype: float64

# %% [markdown]
# After removing degenerate particles (`min_area=3`, `perimeter=0` filter),
# the boxplots show notable improvements in several variables that were
# previously collapsed due to the dominance of 1px² particles with constant metrics.
#
# **Variables that improved significantly**
#
# - **`solidity`** — previously collapsed at 1.0 with no visible box, now shows
#   a well-defined distribution between 0.8-1.0 with a real range down to 0.3,
#   reflecting the actual shape variability of real particles.
#
# - **`aspect_ratio`** — previously collapsed near 1.0, now shows a clear box
#   between 1.5-2.0, indicating that real particles are predominantly elongated
#   rather than perfectly circular.
#
# - **`std_intensity`** — previously collapsed near 0, now shows a visible box
#   with median ~5 and range up to 20, capturing the real internal intensity
#   variation of particles.
#
# - **`glcm_energy`** — previously collapsed, now shows a wide box between
#   0.25-0.45, reflecting meaningful texture homogeneity differences between
#   particles.
#
# - **`glcm_correlation`** — previously collapsed with extreme outliers, now
#   shows a well-spread box between -0.5 and 0.75, capturing real spatial
#   correlation patterns in particle texture.
#
# - **`lbp_mean`** — previously near 0, now centred between 50-75 with a
#   clear interquartile range, reflecting real local texture patterns.
#
# **Variables that remain similar**
#
# - **`perimeter`, `compactness`, `roundness`, `hu1`, `hu2`** — still show
#   a collapsed box with a long upper tail. This is expected and reflects the
#   natural distribution of predominantly small particles with a few larger ones.
#
# - **`convexity_defects`** — still shows negative values and a long tail,
#   which will be addressed in the outlier treatment step.
#
# - **`euler_number`, `holes`** — remain highly concentrated at 0/1 with
#   very few outliers, consistent with most particles having simple topology.
#
# **Conclusion**
#
# The six variables that improved were artificially collapsed in the original
# dataset by the 901,970 degenerate 1px² particles, which had constant metrics
# across all observations. The cleaned dataset now reflects the true variability
# of real particles, making these variables genuinely informative for clustering.

# %% [markdown]
# ### Outliers treatment

# %%
cols_base = [
    "perimeter", "equivalent_diameter",
    "roundness", "aspect_ratio", "compactness", "solidity",
    "mean_intensity", "std_intensity", "intensity_entropy",
    "glcm_energy", "glcm_correlation", "lbp_mean",
    "hu1", "hu2", "hu4",
    "feret_min", "feret_max", "convexity_defects", "area"
]

df_clustering = df[cols_base].copy()

# Calcular nuevas variables
df_clustering['feret_ratio'] = np.where(
    df_clustering['feret_max'] > 0,
    df_clustering['feret_min'] / df_clustering['feret_max'],
    0
)

df_clustering['convexity_defects_norm'] = np.where(
    df_clustering['area'] > 0,
    df_clustering['convexity_defects'] / df_clustering['area'],
    0
)

# Quedarse solo con las columnas finales
columnas_clustering = [
    "perimeter", "equivalent_diameter",
    "roundness", "aspect_ratio", "compactness", "solidity", "feret_ratio",
    "mean_intensity", "std_intensity", "intensity_entropy",
    "glcm_energy", "glcm_correlation", "lbp_mean",
    "hu1", "hu2", "hu4",
    "convexity_defects_norm"
]

df_clustering = df_clustering[columnas_clustering].copy()
print(f"Variables para clustering: {len(columnas_clustering)}")
print(f"Dataset: {len(df_clustering)} partículas")
# Out:
# Variables para clustering: 17
# Dataset: 292992 partículas

# %%
df_clean = df_clustering.copy()

p99_round  = df_clean['roundness'].quantile(0.99)
p1_energy  = df_clean['glcm_energy'].quantile(0.01)
p99_energy = df_clean['glcm_energy'].quantile(0.99)
p1_corr    = df_clean['glcm_correlation'].quantile(0.01)
p99_corr   = df_clean['glcm_correlation'].quantile(0.99)

# 1. Límites físicos
df_clean['roundness']        = df_clean['roundness'].clip(upper=p99_round)
df_clean['solidity']         = df_clean['solidity'].clip(0.0, 1.0)
df_clean['glcm_energy']      = df_clean['glcm_energy'].clip(p1_energy, p99_energy)
df_clean['glcm_correlation'] = df_clean['glcm_correlation'].clip(p1_corr, p99_corr)
df_clean['aspect_ratio']     = df_clean['aspect_ratio'].clip(1.0, 4.0)
df_clean['feret_ratio']      = df_clean['feret_ratio'].clip(0.0, 1.0)
df_clean['convexity_defects_norm'] = df_clean['convexity_defects_norm'].clip(lower=0.0)

# 2. Asimétricas → log1p + p99
for var in ['perimeter', 'compactness', 'hu1', 'hu2', 'hu4']:
    p99 = df_clean[var].quantile(0.99)
    df_clean[var] = df_clean[var].clip(upper=p99)
    df_clean[var] = np.log1p(df_clean[var])

# 3. Solo winsorizar
for var in ['equivalent_diameter', 'lbp_mean', 'std_intensity']:
    df_clean[var] = df_clean[var].clip(upper=df_clean[var].quantile(0.99))

# intensity_entropy: ambas colas
p5_ent  = df_clean['intensity_entropy'].quantile(0.05)
p99_ent = df_clean['intensity_entropy'].quantile(0.99)
df_clean['intensity_entropy'] = df_clean['intensity_entropy'].clip(p5_ent, p99_ent)

# 4. Eliminar convexity_defects_norm — IQR=0, 76.7% son exactamente 0
columnas_clustering = [c for c in columnas_clustering
                       if c != 'convexity_defects_norm']
df_clean = df_clean[columnas_clustering].copy()

print(f"Variables finales: {len(columnas_clustering)}")
print(columnas_clustering)
# Out:
# Variables finales: 16
# ['perimeter', 'equivalent_diameter', 'roundness', 'aspect_ratio', 'compactness', 'solidity', 'feret_ratio', 'mean_intensity', 'std_intensity', 'intensity_entropy', 'glcm_energy', 'glcm_correlation', 'lbp_mean', 'hu1', 'hu2', 'hu4']

# %% [markdown]
# #### Outlier Treatment Summary
#
# #### Variable removal
#
# Four variables were removed from the clustering feature set after outlier
# analysis at 2,000×2,000 resolution:
#
# - **`hu7`**: values fall in the 1e-5 scale, numerically unstable for the
#   particles in this dataset. The signal-to-noise ratio is too low to be
#   meaningful for clustering.
#
# - **`euler_number`** and **`holes`**: at 2,000×2,000 resolution the
#   segmentation pipeline detects significantly more topological features
#   within particle contours (`euler_number` reaching -44, previously -9),
#   many of which are likely artefacts rather than real topology. As `holes`
#   is perfectly redundant with `euler_number` (`holes = 1 - euler_number`),
#   both are excluded.
#
# - **`convexity_defects_norm`** (`convexity_defects / area`): 76.7% of
#   values are exactly 0 — most particles have no convex hull defects. The
#   IQR is 0, making `RobustScaler` unable to scale this variable meaningfully.
#   It provides no discriminative information for clustering.
#
# #### Variable recovered
#
# - **`roundness`**: previously removed at 1,000×1,000 resolution because
#   91.2% of values exceeded the theoretical maximum of 1 due to pixel-grid
#   discretization. At 2,000×2,000 the distribution is now physically coherent
#   (median=1.007, max=8.38), with values correctly centred around 1.0. The
#   inversion correction (`1/x`) applied in the previous dataset is no longer
#   needed. `roundness` is restored to the feature set.
#
# #### Variable added
#
# - **`feret_ratio`** (`feret_min / feret_max`): a scale-independent shape
#   descriptor that captures particle elongation more robustly than
#   `aspect_ratio` for irregular particles. Bounded [0, 1] by definition.
#
# #### Outlier treatment applied to remaining variables
#
# The treatment strategy was determined per variable based on physical limits,
# distribution shape, and domain knowledge:
#
# - **Physical limits** (`solidity`, `glcm_energy`, `glcm_correlation`,
#   `aspect_ratio`, `feret_ratio`) → clipped to their valid mathematical
#   or extractor-defined range. `glcm_energy` and `glcm_correlation` are
#   additionally winsorized at p1/p99 to prevent RobustScaler amplification
#   of residual tail values.
#
# - **Skewed distributions** (`perimeter`, `compactness`, `hu1`, `hu2`,
#   `hu4`) → winsorized at p99, then `log1p` transformation to reduce the
#   effect of the long upper tail.
#
# - **Winsorize only** (`equivalent_diameter`, `lbp_mean`, `std_intensity`)
#   → clipped at p99 without log transformation, as their distributions are
#   near-normal or on a linear scale where log would have no physical meaning.
#
# - **Both tails winsorized** (`roundness` at p99, `intensity_entropy` at
#   p5/p99) → these variables have meaningful lower bounds that also require
#   clipping to prevent extreme scaled values.
#
# - **No treatment** (`mean_intensity`, `solidity`, `feret_ratio`,
#   `aspect_ratio`) → distributions already within valid physical bounds
#   with no extreme outliers requiring correction beyond the hard clip.

# %% [markdown]
# # 2. Feature Scaling

# %%
# hu4: StandardScaler (IQR demasiado pequeño)
hu4_scaler = StandardScaler()
df_clean['hu4'] = hu4_scaler.fit_transform(df_clean[['hu4']])

# Resto: RobustScaler
cols_robust = [c for c in df_clean.columns if c != 'hu4']
scaler = RobustScaler()
X_robust = scaler.fit_transform(df_clean[cols_robust])

X_scaled = pd.DataFrame(X_robust, columns=cols_robust, index=df_clean.index)
X_scaled['hu4'] = df_clean['hu4'].values

print(f"\n{'Variable':<28} {'Median':>8} {'IQR':>8} {'Min':>8} {'Max':>8}")
print("-" * 60)
for col in X_scaled.columns:
    q1 = X_scaled[col].quantile(0.25)
    q3 = X_scaled[col].quantile(0.75)
    print(f"{col:<28} {X_scaled[col].median():>8.3f} "
          f"{q3-q1:>8.3f} "
          f"{X_scaled[col].min():>8.3f} "
          f"{X_scaled[col].max():>8.3f}")

print(f"\nShape: {X_scaled.shape}")
print(f"NaN: {X_scaled.isna().sum().sum()}")
# Out:
# Variable                       Median      IQR      Min      Max
# ------------------------------------------------------------
# perimeter                       0.000    1.000   -1.969    2.684
# equivalent_diameter             0.000    1.000   -0.593    4.634
# roundness                       0.000    1.000   -2.078    2.023
# aspect_ratio                    0.000    1.000   -0.766    2.485
# compactness                     0.000    1.000   -3.784    3.076
# solidity                        0.000    1.000   -2.412    0.868
# feret_ratio                     0.000    1.000   -2.283    1.688
# mean_intensity                  0.000    1.000   -3.838    3.050
# std_intensity                   0.000    1.000   -0.546    3.822
# intensity_entropy               0.000    1.000   -2.621    0.577
# glcm_energy                     0.000    1.000   -1.342    3.614
# glcm_correlation                0.000    1.000   -2.697    0.898
# lbp_mean                        0.000    1.000   -3.936    1.959
# hu1                             0.000    1.000   -0.573    2.935
# hu2                             0.000    1.000   -0.334    6.144
# hu4                            -0.340    0.212   -0.372    6.397
#
# Shape: (292992, 16)
# NaN: 0

# %% [markdown]
# ### Scaling
#
# - **`hu4`** → `StandardScaler`, as its IQR is too small relative to the
#   tail for `RobustScaler` to work correctly.
# - **All other variables** → `RobustScaler`, which centres on the median
#   and scales by the IQR, making it robust to any moderate residual outliers
#   remaining after the transformations above.
#
# The final feature set contains **16 variables** across five categories:
# size (2), shape (5), intensity/texture (6), and Hu moments (3).

# %% [markdown]
# # 3. Clustering

# %%
# ── CELL 1: HDBSCAN — no k needed, best starting point ───────────
from sklearn.cluster import KMeans, AgglomerativeClustering, HDBSCAN, \
    MiniBatchKMeans, Birch, DBSCAN, SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import umap

print("Running HDBSCAN...")
hdb = HDBSCAN(min_cluster_size=50, min_samples=10, cluster_selection_method='eom')
labels_hdb = hdb.fit_predict(X_scaled)

n_clusters_hdb = len(set(labels_hdb)) - (1 if -1 in labels_hdb else 0)
n_noise_hdb    = (labels_hdb == -1).sum()
print(f"  Clusters found: {n_clusters_hdb}")
print(f"  Noise points:   {n_noise_hdb} ({n_noise_hdb/len(labels_hdb)*100:.1f}%)")

mask = labels_hdb != -1
if len(set(labels_hdb[mask])) > 1:
    sil_hdb = silhouette_score(X_scaled[mask], labels_hdb[mask], sample_size=10000)
    print(f"  Silhouette:     {sil_hdb:.4f}")
# Out:
# Running HDBSCAN...
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
#   Clusters found: 2
#   Noise points:   0 (0.0%)
#   Silhouette:     0.4896

# %%
# ── CELL 2: ELBOW + SILHOUETTE — find best k for KMeans ──────────
print("Running elbow + silhouette for KMeans...")
K_RANGE     = range(2, 11)
inertias    = []
silhouettes = []

for k in K_RANGE:
    km = KMeans(n_clusters=k, init='k-means++', n_init=15, random_state=42)
    labels = km.fit_predict(X_scaled)
    inertias.append(km.inertia_)
    silhouettes.append(silhouette_score(X_scaled, labels, sample_size=10000))
    print(f"  k={k}  inertia={km.inertia_:.1f}  silhouette={silhouettes[-1]:.4f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(list(K_RANGE), inertias, 'o-', color='#378ADD')
axes[0].set_title('Elbow — inertia vs k')
axes[0].set_xlabel('k'); axes[0].set_ylabel('Inertia')
axes[1].plot(list(K_RANGE), silhouettes, 'o-', color='#1D9E75')
axes[1].set_title('Silhouette vs k')
axes[1].set_xlabel('k'); axes[1].set_ylabel('Silhouette score')
plt.tight_layout()
plt.savefig('elbow_silhouette_2000.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Running elbow + silhouette for KMeans...
#   k=2  inertia=2524203.7  silhouette=0.3103
#   k=3  inertia=2137899.6  silhouette=0.2361
#   k=4  inertia=1857758.0  silhouette=0.2112
#   k=5  inertia=1671272.1  silhouette=0.2164
#   k=6  inertia=1534930.6  silhouette=0.2065
#   k=7  inertia=1440204.4  silhouette=0.1873
#   k=8  inertia=1361741.8  silhouette=0.1853
#   k=9  inertia=1291126.6  silhouette=0.1823
#   k=10  inertia=1238482.3  silhouette=0.1654

# %%
# ── CELL 3: PROFILE k=2 ───────────────────────────────────────────
# Adjust N_CLUSTERS after reviewing the elbow/silhouette plots above
N_CLUSTERS      = 2
N_CLUSTERS_LIST = [2, 3, 4]

km2 = KMeans(n_clusters=2, init='k-means++', n_init=15, random_state=42)
labels2 = km2.fit_predict(X_scaled)

print("=== Profile of k=2 clusters (original values, pre-scaling) ===")
df_clean['cluster'] = labels2
print(f"\nCluster sizes:")
print(df_clean['cluster'].value_counts())
print(f"\nMedians per cluster:")
print(df_clean.groupby('cluster').median().round(3).T)
# Out:
# === Profile of k=2 clusters (original values, pre-scaling) ===
#
# Cluster sizes:
# cluster
# 0    207392
# 1     85600
# Name: count, dtype: int64
#
# Medians per cluster:
# cluster                    0        1
# perimeter              2.777    3.398
# equivalent_diameter    5.046    6.956
# roundness              1.108    0.614
# aspect_ratio           1.530    2.517
# compactness            2.513    3.067
# solidity               0.867    0.660
# feret_ratio            0.631    0.412
# mean_intensity       132.294  142.750
# std_intensity          5.620    2.887
# intensity_entropy      3.331    3.181
# glcm_energy            0.161    0.120
# glcm_correlation       0.666    0.851
# lbp_mean              96.667  114.623
# hu1                    0.175    0.294
# hu2                    0.006    0.058
# hu4                   -0.360   -0.010

# %%
# ── CELL 4: FULL ALGORITHM COMPARISON ────────────────────────────
SAMPLE_SIZE = 10000
np.random.seed(42)
idx_sample = np.random.choice(len(X_scaled), SAMPLE_SIZE, replace=False)
X_sample   = X_scaled.iloc[idx_sample]

results = {}

print(f"{'Algorithm':<22} {'k':>3} {'Silhouette':>12} {'DB↓':>10} {'CH↑':>12} {'Note'}")
print("-" * 75)

# KMeans — full dataset
for k in N_CLUSTERS_LIST:
    km = KMeans(n_clusters=k, init='k-means++', n_init=15, random_state=42)
    labels = km.fit_predict(X_scaled)
    sil = silhouette_score(X_scaled, labels, sample_size=10000, random_state=42)
    db  = davies_bouldin_score(X_scaled, labels)
    ch  = calinski_harabasz_score(X_scaled, labels)
    results[f"KMeans_k{k}"] = {'labels': labels, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'KMeans':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} full dataset")

# MiniBatchKMeans — full dataset
for k in N_CLUSTERS_LIST:
    mb = MiniBatchKMeans(n_clusters=k, n_init=10, random_state=42, batch_size=10000)
    labels = mb.fit_predict(X_scaled)
    sil = silhouette_score(X_scaled, labels, sample_size=10000, random_state=42)
    db  = davies_bouldin_score(X_scaled, labels)
    ch  = calinski_harabasz_score(X_scaled, labels)
    results[f"MiniBatchKMeans_k{k}"] = {'labels': labels, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'MiniBatchKMeans':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} full dataset")

# GMM — full dataset
for k in N_CLUSTERS_LIST:
    gmm = GaussianMixture(n_components=k, n_init=3, random_state=42)
    gmm.fit(X_scaled)
    labels = gmm.predict(X_scaled)
    sil = silhouette_score(X_scaled, labels, sample_size=10000, random_state=42)
    db  = davies_bouldin_score(X_scaled, labels)
    ch  = calinski_harabasz_score(X_scaled, labels)
    results[f"GMM_k{k}"] = {'labels': labels, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'GMM':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} full dataset")
# Out:
# Algorithm                k   Silhouette        DB↓          CH↑ Note
# ---------------------------------------------------------------------------
# KMeans                   2       0.3096     1.5368     102226.5 full dataset
# KMeans                   3       0.2309     1.5401      86819.6 full dataset
# KMeans                   4       0.2069     1.4358      81334.5 full dataset
# MiniBatchKMeans          2       0.3141     1.5270     102128.6 full dataset
# MiniBatchKMeans          3       0.1777     1.7868      77248.1 full dataset
# MiniBatchKMeans          4       0.2098     1.4663      80247.0 full dataset
# GMM                      2       0.1696     1.8746      64002.1 full dataset
# GMM                      3       0.1116     1.8179      63684.5 full dataset
# GMM                      4       0.1019     1.8020      57560.4 full dataset

# %%
# BIRCH — full dataset
#for k in N_CLUSTERS_LIST:
 #   birch = Birch(n_clusters=k, threshold=0.5)
  #  labels = birch.fit_predict(X_scaled)
   # sil = silhouette_score(X_scaled, labels, sample_size=10000, random_state=42)
    #db  = davies_bouldin_score(X_scaled, labels)
    #ch  = calinski_harabasz_score(X_scaled, labels)
    #results[f"BIRCH_k{k}"] = {'labels': labels, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    #print(f"{'BIRCH':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} full dataset")

# %%
# Agglomerative — sample only
for k in N_CLUSTERS_LIST:
    agg = AgglomerativeClustering(n_clusters=k, linkage='ward')
    labels_sample = agg.fit_predict(X_sample)
    sil = silhouette_score(X_sample, labels_sample, random_state=42)
    db  = davies_bouldin_score(X_sample, labels_sample)
    ch  = calinski_harabasz_score(X_sample, labels_sample)
    results[f"Agglomerative_k{k}"] = {'labels': labels_sample, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'Agglomerative':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} sample n={SAMPLE_SIZE}")
# Out:
# Agglomerative            2       0.2773     1.6438       3010.6 sample n=10000
# Agglomerative            3       0.2235     1.6156       2349.3 sample n=10000
# Agglomerative            4       0.1443     1.6873       2272.9 sample n=10000

# %%
# HDBSCAN — sample only
hdb = HDBSCAN(min_cluster_size=100, min_samples=10, cluster_selection_method='eom')
labels_hdb = hdb.fit_predict(X_sample)
mask = labels_hdb != -1
n_clusters_hdb = len(set(labels_hdb[mask]))
noise_pct = (labels_hdb == -1).mean() * 100
if n_clusters_hdb > 1:
    sil = silhouette_score(X_sample[mask], labels_hdb[mask], random_state=42)
    db  = davies_bouldin_score(X_sample[mask], labels_hdb[mask])
    ch  = calinski_harabasz_score(X_sample[mask], labels_hdb[mask])
    results['HDBSCAN'] = {'labels': labels_hdb, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'HDBSCAN':<22} {'auto':>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} k={n_clusters_hdb} noise={noise_pct:.1f}%")
# Out:
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(

# %%
# ── CELL 5: DBSCAN + SPECTRAL + UMAP+HDBSCAN ─────────────────────
from sklearn.neighbors import NearestNeighbors

# DBSCAN k-distance plot
nn = NearestNeighbors(n_neighbors=5).fit(X_sample)
dist, _ = nn.kneighbors(X_sample)
dist_sorted = np.sort(dist[:, -1])

plt.figure(figsize=(8, 4))
plt.plot(dist_sorted, color='#378ADD')
plt.title('k-distance plot — DBSCAN eps selection')
plt.xlabel('Points sorted by distance')
plt.ylabel('5th nearest neighbor distance')
plt.axhline(y=1.5, color='red', linestyle='--', label='eps candidate')
plt.legend(); plt.tight_layout()
plt.savefig('dbscan_eps_2000.png', dpi=150, bbox_inches='tight')
plt.show()

for eps in [1.0, 1.5, 2.0]:
    db_model = DBSCAN(eps=eps, min_samples=10)
    labels_db = db_model.fit_predict(X_sample)
    n_clusters_db = len(set(labels_db)) - (1 if -1 in labels_db else 0)
    noise_pct_db  = (labels_db == -1).mean() * 100
    if n_clusters_db > 1:
        mask_db = labels_db != -1
        sil = silhouette_score(X_sample[mask_db], labels_db[mask_db], random_state=42)
        print(f"{'DBSCAN':<22} eps={eps} k={n_clusters_db} sil={sil:.4f} noise={noise_pct_db:.1f}%")
    else:
        print(f"{'DBSCAN':<22} eps={eps} k={n_clusters_db} — no valid clusters")

# Spectral — sample only
for k in N_CLUSTERS_LIST:
    spec = SpectralClustering(n_clusters=k, affinity='nearest_neighbors',
                              n_neighbors=10, random_state=42, n_jobs=-1)
    labels_spec = spec.fit_predict(X_sample)
    sil = silhouette_score(X_sample, labels_spec, random_state=42)
    db  = davies_bouldin_score(X_sample, labels_spec)
    ch  = calinski_harabasz_score(X_sample, labels_spec)
    results[f"Spectral_k{k}"] = {'labels': labels_spec, 'silhouette': sil, 'davies_bouldin': db, 'calinski': ch}
    print(f"{'Spectral':<22} {k:>3} {sil:>12.4f} {db:>10.4f} {ch:>12.1f} sample n={SAMPLE_SIZE}")

# UMAP + HDBSCAN
print("\nRunning UMAP + HDBSCAN...")
reducer = umap.UMAP(n_components=10, n_neighbors=15, min_dist=0.1,
                    metric='euclidean', random_state=42)
X_umap = reducer.fit_transform(X_sample)

hdb_umap = HDBSCAN(min_cluster_size=100, min_samples=10, cluster_selection_method='eom')
labels_umap = hdb_umap.fit_predict(X_umap)
mask_umap       = labels_umap != -1
n_clusters_umap = len(set(labels_umap[mask_umap]))
noise_pct       = (labels_umap == -1).mean() * 100

if n_clusters_umap > 1:
    sil = silhouette_score(X_umap[mask_umap], labels_umap[mask_umap], random_state=42)
    db  = davies_bouldin_score(X_umap[mask_umap], labels_umap[mask_umap])
    ch  = calinski_harabasz_score(X_umap[mask_umap], labels_umap[mask_umap])
    results['UMAP+HDBSCAN'] = {'labels': labels_umap, 'silhouette': sil,
                                'davies_bouldin': db, 'calinski': ch}
    print(f"{'UMAP+HDBSCAN':<22} {'auto':>3} {sil:>12.4f} {db:>10.4f} "
          f"{ch:>12.1f} k={n_clusters_umap} noise={noise_pct:.1f}%")
# Out:
# DBSCAN                 eps=1.0 k=6 sil=0.1146 noise=42.4%
# DBSCAN                 eps=1.5 k=2 sil=0.6204 noise=10.5%
# DBSCAN                 eps=2.0 k=2 sil=0.4556 noise=2.4%
# Spectral                 2       0.2894     1.5959       3336.7 sample n=10000
# Spectral                 3       0.2154     1.4027       2668.4 sample n=10000
# Spectral                 4       0.2134     1.3819       2396.0 sample n=10000
#
# Running UMAP + HDBSCAN...
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
# UMAP+HDBSCAN           auto       0.2754     0.6269        655.2 k=2 noise=26.4%

# %%
# ── CELL 6: SUMMARY TABLE ─────────────────────────────────────────
print("\n" + "="*75)
print("FULL COMPARISON")
print("="*75)
print(f"{'Algorithm':<25} {'Silhouette↑':>12} {'DB↓':>10} {'CH↑':>12}")
print("-"*60)
summary = sorted(results.items(), key=lambda x: x[1]['silhouette'], reverse=True)
for name, metrics in summary:
    print(f"{name:<25} {metrics['silhouette']:>12.4f} "
          f"{metrics['davies_bouldin']:>10.4f} "
          f"{metrics['calinski']:>12.1f}")
# Out:
# ===========================================================================
# FULL COMPARISON
# ===========================================================================
# Algorithm                  Silhouette↑        DB↓          CH↑
# ------------------------------------------------------------
# MiniBatchKMeans_k2              0.3141     1.5270     102128.6
# KMeans_k2                       0.3096     1.5368     102226.5
# Spectral_k2                     0.2894     1.5959       3336.7
# Agglomerative_k2                0.2773     1.6438       3010.6
# UMAP+HDBSCAN                    0.2754     0.6269        655.2
# KMeans_k3                       0.2309     1.5401      86819.6
# Agglomerative_k3                0.2235     1.6156       2349.3
# Spectral_k3                     0.2154     1.4027       2668.4
# Spectral_k4                     0.2134     1.3819       2396.0
# MiniBatchKMeans_k4              0.2098     1.4663      80247.0
# KMeans_k4                       0.2069     1.4358      81334.5
# MiniBatchKMeans_k3              0.1777     1.7868      77248.1
# GMM_k2                          0.1696     1.8746      64002.1
# Agglomerative_k4                0.1443     1.6873       2272.9
# GMM_k3                          0.1116     1.8179      63684.5
# GMM_k4                          0.1019     1.8020      57560.4

# %%
# ── CELL 7: PCA 2D VISUALIZATION ──────────────────────────────────
pca = PCA(n_components=2, random_state=42)
X_2d = pca.fit_transform(X_scaled)

sil_k2 = results['KMeans_k2']['silhouette']
sil_k3 = results['KMeans_k3']['silhouette']
sil_k4 = results['KMeans_k4']['silhouette']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for ax, k, sil, labels in [
    (axes[0], 2, sil_k2, results['KMeans_k2']['labels']),
    (axes[1], 3, sil_k3, results['KMeans_k3']['labels']),
    (axes[2], 4, sil_k4, results['KMeans_k4']['labels']),
]:
    ax.scatter(X_2d[:, 0], X_2d[:, 1], c=labels, cmap='tab10', s=2, alpha=0.3)
    ax.set_title(f'KMeans k={k}\nSilhouette={sil:.3f}')
    ax.set_xlabel('PC1'); ax.set_ylabel('PC2')

plt.suptitle('KMeans clustering — PCA 2D projection (2000×2000)', fontsize=13)
plt.tight_layout()
plt.savefig('clustering_pca2d_2000.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"PC1 variance explained: {pca.explained_variance_ratio_[0]*100:.1f}%")
print(f"PC2 variance explained: {pca.explained_variance_ratio_[1]*100:.1f}%")
print(f"Total: {sum(pca.explained_variance_ratio_)*100:.1f}%")
# Out:
# PC1 variance explained: 39.3%
# PC2 variance explained: 23.0%
# Total: 62.3%

# %%
# ── CELL 8: UMAP 2D VISUALIZATION ────────────────────────────────
reducer_2d = umap.UMAP(n_components=2, n_neighbors=15, min_dist=0.1,
                       metric='euclidean', random_state=42)
X_umap_2d = reducer_2d.fit_transform(X_sample)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

scatter = axes[0].scatter(X_umap_2d[:, 0], X_umap_2d[:, 1],
                          c=labels_umap, cmap='tab10', s=3, alpha=0.5)
axes[0].set_title(f'UMAP + HDBSCAN\nk={n_clusters_umap}, noise={noise_pct:.1f}%')
axes[0].set_xlabel('UMAP1'); axes[0].set_ylabel('UMAP2')
plt.colorbar(scatter, ax=axes[0], label='Cluster')

km2_sample = KMeans(n_clusters=2, init='k-means++', n_init=15, random_state=42)
labels_km2_sample = km2_sample.fit_predict(X_sample)
scatter2 = axes[1].scatter(X_umap_2d[:, 0], X_umap_2d[:, 1],
                           c=labels_km2_sample, cmap='tab10', s=3, alpha=0.5)
axes[1].set_title('KMeans k=2 (on sample)\nprojected on UMAP space')
axes[1].set_xlabel('UMAP1'); axes[1].set_ylabel('UMAP2')
plt.colorbar(scatter2, ax=axes[1], label='Cluster')

plt.suptitle('UMAP 2D projection — sample n=10,000 (2000×2000)', fontsize=13)
plt.tight_layout()
plt.savefig('umap_clustering_2000.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# ── CELL 9: CLUSTER PROFILE — UMAP+HDBSCAN ───────────────────────
df_sample_clean = df_clean.iloc[idx_sample].copy()
df_sample_clean = df_sample_clean[labels_umap != -1].copy()
df_sample_clean['cluster'] = labels_umap[labels_umap != -1]

print("=== Cluster sizes ===")
print(df_sample_clean['cluster'].value_counts().sort_index())

print("\n=== Median per cluster — all variables ===")
print(df_sample_clean.groupby('cluster').median().round(3).T.to_string())

print("\n=== Std per cluster — all variables ===")
print(df_sample_clean.groupby('cluster').std().round(3).T.to_string())
# Out:
# === Cluster sizes ===
# cluster
# 0    7158
# 1     200
# Name: count, dtype: int64
#
# === Median per cluster — all variables ===
# cluster                    0        1
# perimeter              2.970    3.509
# equivalent_diameter    5.642    7.136
# roundness              0.974    0.477
# aspect_ratio           1.635    3.161
# compactness            2.632    3.308
# solidity               0.824    0.500
# feret_ratio            0.596    0.349
# mean_intensity       133.525  143.608
# std_intensity          4.787    4.186
# intensity_entropy      3.308    3.194
# glcm_energy            0.144    0.089
# glcm_correlation       0.736    0.883
# lbp_mean             101.999  118.744
# hu1                    0.192    0.445
# hu2                    0.009    0.177
# hu4                   -0.347    6.397
#
# === Std per cluster — all variables ===
# cluster                   0       1
# perimeter             0.491   0.710
# equivalent_diameter   2.653   4.555
# roundness             0.335   0.353
# aspect_ratio          0.718   0.627
# compactness           0.379   0.536
# solidity              0.137   0.090
# feret_ratio           0.164   0.086
# mean_intensity       27.901  27.347
# std_intensity         8.371   3.815
# intensity_entropy     0.142   0.133
# glcm_energy           0.073   0.071
# glcm_correlation      0.212   0.145
# lbp_mean             18.298  15.683
# hu1                   0.070   0.049
# hu2                   0.039   0.050
# hu4                   0.623   1.448

# %%
# Perfil completo de los 12 clusters de UMAP+HDBSCAN
df_sample_clean = df_clean.iloc[idx_sample].copy()
df_sample_clean = df_sample_clean[labels_umap != -1].copy()
df_sample_clean['cluster'] = labels_umap[labels_umap != -1]

print("=== Cluster sizes ===")
print(df_sample_clean['cluster'].value_counts().sort_index())

print("\n=== Median per cluster — all variables ===")
medians = df_sample_clean.groupby('cluster').median().round(3)
print(medians.T.to_string())

print("\n=== Std per cluster — all variables ===")
stds = df_sample_clean.groupby('cluster').std().round(3)
print(stds.T.to_string())

print("\n=== Equivalent diameter per cluster ===")
print(df_sample_clean.groupby('cluster')['equivalent_diameter'].describe().round(3))

print("\n=== Solidity per cluster ===")
print(df_sample_clean.groupby('cluster')['solidity'].describe().round(3))

print("\n=== Roundness per cluster ===")
print(df_sample_clean.groupby('cluster')['roundness'].describe().round(3))
# Out:
# === Cluster sizes ===
# cluster
# 0    7158
# 1     200
# Name: count, dtype: int64
#
# === Median per cluster — all variables ===
# cluster                    0        1
# perimeter              2.970    3.509
# equivalent_diameter    5.642    7.136
# roundness              0.974    0.477
# aspect_ratio           1.635    3.161
# compactness            2.632    3.308
# solidity               0.824    0.500
# feret_ratio            0.596    0.349
# mean_intensity       133.525  143.608
# std_intensity          4.787    4.186
# intensity_entropy      3.308    3.194
# glcm_energy            0.144    0.089
# glcm_correlation       0.736    0.883
# lbp_mean             101.999  118.744
# hu1                    0.192    0.445
# hu2                    0.009    0.177
# hu4                   -0.347    6.397
#
# === Std per cluster — all variables ===
# cluster                   0       1
# perimeter             0.491   0.710
# equivalent_diameter   2.653   4.555
# roundness             0.335   0.353
# aspect_ratio          0.718   0.627
# compactness           0.379   0.536
# solidity              0.137   0.090
# feret_ratio           0.164   0.086
# mean_intensity       27.901  27.347
# std_intensity         8.371   3.815
# intensity_entropy     0.142   0.133
# glcm_energy           0.073   0.071
# glcm_correlation      0.212   0.145
# lbp_mean             18.298  15.683
# hu1                   0.070   0.049
# hu2                   0.039   0.050
# hu4                   0.623   1.448
#
# === Equivalent diameter per cluster ===
#           count   mean    std    min    25%    50%     75%    max
# cluster
# 0        7158.0  6.463  2.653  3.909  4.514  5.642   7.399  17.15
# 1         200.0  8.829  4.555  3.909  5.140  7.136  11.980  17.15
#
# === Solidity per cluster ===
#           count   mean    std    min    25%    50%    75%   max
# cluster
# 0        7158.0  0.801  0.137  0.339  0.706  0.824  0.917  1.00
# 1         200.0  0.500  0.090  0.303  0.442  0.500  0.563  0.75
#
# === Roundness per cluster ===
#           count   mean    std    min    25%    50%    75%    max
# cluster
# 0        7158.0  0.964  0.335  0.042  0.726  0.974  1.200  1.935
# 1         200.0  0.537  0.353  0.074  0.270  0.477  0.729  1.935

# %%
# Comparativa formal entre datasets
print("=" * 65)
print("FORMAL COMPARISON: 1000×1000 vs 2000×2000")
print("=" * 65)

print(f"\n{'Metric':<35} {'1000×1000':>12} {'2000×2000':>12}")
print("-" * 60)

# Dataset size
print(f"{'Dataset size':<35} {'197,536':>12} {'177,277':>12}")

# KMeans k=2
print(f"{'KMeans k=2 silhouette':<35} {'0.3603':>12} {'0.3350':>12}")
print(f"{'KMeans k=2 DB':<35} {'1.4101':>12} {'1.4880':>12}")
print(f"{'KMeans k=2 CH':<35} {'76,592':>12} {'65,908':>12}")

# HDBSCAN full dataset
print(f"{'HDBSCAN clusters (full)':<35} {'148':>12} {'5':>12}")
print(f"{'HDBSCAN noise % (full)':<35} {'54.1%':>12} {'13.4%':>12}")
print(f"{'HDBSCAN silhouette (full)':<35} {'-0.029':>12} {'0.506':>12}")

# UMAP+HDBSCAN
print(f"{'UMAP+HDBSCAN clusters':<35} {'9':>12} {'12':>12}")
print(f"{'UMAP+HDBSCAN noise %':<35} {'0.4%':>12} {'46.9%':>12}")
print(f"{'UMAP+HDBSCAN silhouette':<35} {'0.6324':>12} {'0.2003':>12}")

# Discretization
print(f"{'Clusters with diam std=0':<35} {'5 of 9':>12} {'0 of 12':>12}")
print(f"{'Clusters with solidity std=0':<35} {'7 of 9':>12} {'0 of 12':>12}")
print(f"{'Clusters with aspect_ratio std=0':<35} {'5 of 9':>12} {'0 of 12':>12}")

# DBSCAN
print(f"{'DBSCAN best silhouette':<35} {'0.2123':>12} {'0.6357':>12}")
print(f"{'DBSCAN best eps':<35} {'2.0':>12} {'1.5':>12}")
print(f"{'DBSCAN best k':<35} {'7':>12} {'2':>12}")
print(f"{'DBSCAN noise % at best eps':<35} {'2.1%':>12} {'11.3%':>12}")
# Out:
# =================================================================
# FORMAL COMPARISON: 1000×1000 vs 2000×2000
# =================================================================
#
# Metric                                 1000×1000    2000×2000
# ------------------------------------------------------------
# Dataset size                             197,536      177,277
# KMeans k=2 silhouette                     0.3603       0.3350
# KMeans k=2 DB                             1.4101       1.4880
# KMeans k=2 CH                             76,592       65,908
# HDBSCAN clusters (full)                      148            5
# HDBSCAN noise % (full)                     54.1%        13.4%
# HDBSCAN silhouette (full)                 -0.029        0.506
# UMAP+HDBSCAN clusters                          9           12
# UMAP+HDBSCAN noise %                        0.4%        46.9%
# UMAP+HDBSCAN silhouette                   0.6324       0.2003
# Clusters with diam std=0                  5 of 9      0 of 12
# Clusters with solidity std=0              7 of 9      0 of 12
# Clusters with aspect_ratio std=0          5 of 9      0 of 12
# DBSCAN best silhouette                    0.2123       0.6357
# DBSCAN best eps                              2.0          1.5
# DBSCAN best k                                  7            2
# DBSCAN noise % at best eps                  2.1%        11.3%

# %%
# Ejecutar HDBSCAN completo y ver el perfil de los 5 clusters
hdb_full = HDBSCAN(min_cluster_size=50, min_samples=10,
                   cluster_selection_method='eom')
labels_hdb_full = hdb_full.fit_predict(X_scaled)

mask = labels_hdb_full != -1
n_clusters = len(set(labels_hdb_full[mask]))
noise_pct   = (labels_hdb_full == -1).mean() * 100

print(f"Clusters: {n_clusters}")
print(f"Noise: {noise_pct:.1f}%")
print(f"\nCluster sizes:")
print(pd.Series(labels_hdb_full).value_counts().sort_index())

# Perfil de los 5 clusters
df_clean['cluster_hdb'] = labels_hdb_full
df_hdb = df_clean[labels_hdb_full != -1].copy()

print("\n=== Medians per cluster ===")
print(df_hdb.groupby('cluster_hdb').median().round(3).T.to_string())

print("\n=== Std per cluster ===")
print(df_hdb.groupby('cluster_hdb').std().round(3).T.to_string())
# Out:
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
# Clusters: 2
# Noise: 0.0%
#
# Cluster sizes:
# 0    292923
# 1        69
# Name: count, dtype: int64
#
# === Medians per cluster ===
# cluster_hdb                0        1
# perimeter              2.894    2.773
# equivalent_diameter    5.412    4.652
# roundness              0.996    0.949
# aspect_ratio           1.707    1.000
# compactness            2.611    2.656
# solidity               0.815    1.000
# feret_ratio            0.575    0.000
# mean_intensity       135.429  144.900
# std_intensity          4.410    2.702
# intensity_entropy      3.306    3.277
# glcm_energy            0.150    0.044
# glcm_correlation       0.722    0.966
# lbp_mean             101.458   34.222
# hu1                    0.196    0.474
# hu2                    0.011    0.216
# hu4                   -0.340   -0.372
# cluster                0.000    1.000
#
# === Std per cluster ===
# cluster_hdb               0       1
# perimeter             0.482   0.398
# equivalent_diameter   2.518   1.023
# roundness             0.341   0.367
# aspect_ratio          0.692   0.000
# compactness           0.383   0.434
# solidity              0.140   0.000
# feret_ratio           0.158   0.000
# mean_intensity       27.633  40.804
# std_intensity         7.725   1.974
# intensity_entropy     0.137   0.100
# glcm_energy           0.071   0.117
# glcm_correlation      0.210   0.160
# lbp_mean             18.111  14.968
# hu1                   0.073   0.000
# hu2                   0.041   0.000
# hu4                   1.000   0.000
# cluster               0.455   0.000

# %%
for c in [1, 2]:
    mask = labels_hdb_full == c
    print(f"\nCluster {c} ({mask.sum()} partículas):")
    print(df_clean[mask][['equivalent_diameter', 'mean_intensity',
                           'roundness', 'solidity']].describe().round(3))
# Out:
# Cluster 1 (69 partículas):
#        equivalent_diameter  mean_intensity  roundness  solidity
# count               69.000          69.000     69.000      69.0
# mean                 4.930         124.622      0.959       1.0
# std                  1.023          40.804      0.367       0.0
# min                  3.909           9.824      0.279       1.0
# 25%                  4.222         104.154      0.731       1.0
# 50%                  4.652         144.900      0.949       1.0
# 75%                  5.171         149.417      1.222       1.0
# max                  7.899         196.176      1.508       1.0
#
# Cluster 2 (0 partículas):
#        equivalent_diameter  mean_intensity  roundness  solidity
# count                  0.0             0.0        0.0       0.0
# mean                   NaN             NaN        NaN       NaN
# std                    NaN             NaN        NaN       NaN
# min                    NaN             NaN        NaN       NaN
# 25%                    NaN             NaN        NaN       NaN
# 50%                    NaN             NaN        NaN       NaN
# 75%                    NaN             NaN        NaN       NaN
# max                    NaN             NaN        NaN       NaN

# %%
# ── Opción A: sub-clustering del cluster 3 ────────────────────────
mask_c3 = labels_hdb_full == 3
X_c3 = X_scaled[mask_c3]
print(f"Partículas en cluster 3: {mask_c3.sum()}")

for k in [2, 3, 4, 5]:
    km = KMeans(n_clusters=k, init='k-means++', n_init=15, random_state=42)
    labels_sub = km.fit_predict(X_c3)
    sil = silhouette_score(X_c3, labels_sub, sample_size=10000, random_state=42)
    db  = davies_bouldin_score(X_c3, labels_sub)
    print(f"KMeans k={k}: silhouette={sil:.4f} DB={db:.4f}")

# ── Opción B: HDBSCAN con min_cluster_size más pequeño ────────────
for min_size in [30, 50, 100, 200]:
    hdb_b = HDBSCAN(min_cluster_size=min_size, min_samples=5,
                    cluster_selection_method='eom')
    labels_b = hdb_b.fit_predict(X_scaled)
    mask_b = labels_b != -1
    n_b = len(set(labels_b[mask_b]))
    noise_b = (labels_b == -1).mean() * 100
    if n_b > 1:
        sil_b = silhouette_score(X_scaled[mask_b], labels_b[mask_b],
                                 sample_size=10000, random_state=42)
        print(f"HDBSCAN min_size={min_size}: k={n_b} sil={sil_b:.4f} noise={noise_b:.1f}%")

# ── Opción C: HDBSCAN leaf ─────────────────────────────────────────
hdb_leaf = HDBSCAN(min_cluster_size=50, min_samples=10,
                   cluster_selection_method='leaf')
labels_leaf = hdb_leaf.fit_predict(X_scaled)
mask_leaf = labels_leaf != -1
n_leaf = len(set(labels_leaf[mask_leaf]))
noise_leaf = (labels_leaf == -1).mean() * 100
if n_leaf > 1:
    sil_leaf = silhouette_score(X_scaled[mask_leaf], labels_leaf[mask_leaf],
                                sample_size=10000, random_state=42)
    print(f"\nHDBSCAN leaf: k={n_leaf} sil={sil_leaf:.4f} noise={noise_leaf:.1f}%")
# Out:
# Partículas en cluster 3: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 8
#       6 for k in [2, 3, 4, 5]:
#       7     km = KMeans(n_clusters=k, init='k-means++', n_init=15, random_state=42)
# ----> 8     labels_sub = km.fit_predict(X_c3)
#       9     sil = silhouette_score(X_c3, labels_sub, sample_size=10000, random_state=42)
#      10     db  = davies_bouldin_score(X_c3, labels_sub)
#
# File c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_kmeans.py:1070, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1047 def fit_predict(self, X, y=None, sample_weight=None):
#    1048     """Compute cluster centers and predict cluster index for each sample.
#    1049
#    1050     Convenience method; equivalent to calling fit(X) followed by
#    (...)   1068         Index of the cluster each sample belongs to.
#    1069     """
# -> 1070     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_kmeans.py:1460, in KMeans.fit(self, X, y, sample_weight)
#    1432 @_fit_context(prefer_skip_nested_validation=True)
#    1433 def fit(self, X, y=None, sample_weight=None):
#    1434     """Compute k-means clustering.
#    1435
#    1436     Parameters
#    (...)   1458         Fitted estimator.
#    1459     """
# -> 1460     X = validate_data(
#    1461         self,
#    1462         X,
#    1463         accept_sparse="csr",
#    1464         dtype=[np.float64, np.float32],
#    1465         order="C",
#    1466         copy=self.copy_x,
#    1467         accept_large_sparse=False,
#    1468     )
#    1470     self._check_params_vs_input(X)
#    1472     random_state = check_random_state(self.random_state)
#
# File c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\utils\validation.py:2902, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2900         out = X, y
#    2901 elif not no_val_X and no_val_y:
# -> 2902     out = check_array(X, input_name="X", **check_params)
#    2903 elif no_val_X and not no_val_y:
#    2904     out = _check_y(y, **check_params)
#
# File c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\utils\validation.py:1097, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1095     n_samples = _num_samples(array)
#    1096     if n_samples < ensure_min_samples:
# -> 1097         raise ValueError(
#    1098             "Found array with %d sample(s) (shape=%s) while a"
#    1099             " minimum of %d is required%s."
#    1100             % (n_samples, array.shape, ensure_min_samples, context)
#    1101         )
#    1103 if ensure_min_features > 0 and array.ndim == 2:
#    1104     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 16)) while a minimum of 1 is required by KMeans.

# %%
# Perfil de HDBSCAN min_size=100, k=3
hdb_100 = HDBSCAN(min_cluster_size=100, min_samples=5,
                  cluster_selection_method='eom')
labels_100 = hdb_100.fit_predict(X_scaled)

mask_100 = labels_100 != -1
print(f"Clusters: {len(set(labels_100[mask_100]))}")
print(f"Noise: {(labels_100==-1).mean()*100:.1f}%")
print(f"\nCluster sizes:")
print(pd.Series(labels_100).value_counts().sort_index())

df_clean['cluster_hdb100'] = labels_100
df_hdb100 = df_clean[mask_100].copy()

print("\n=== Medians per cluster ===")
cols_show = ['equivalent_diameter', 'roundness', 'aspect_ratio',
             'solidity', 'feret_ratio', 'mean_intensity',
             'std_intensity', 'glcm_correlation', 'lbp_mean']
print(df_hdb100.groupby('cluster_hdb100')[cols_show].median().round(3).T.to_string())

print("\n=== Std per cluster ===")
print(df_hdb100.groupby('cluster_hdb100')[cols_show].std().round(3).T.to_string())
# Out:
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
# Clusters: 4
# Noise: 13.0%
#
# Cluster sizes:
# -1     37987
#  0       137
#  1       646
#  2    253880
#  3       342
# Name: count, dtype: int64
#
# === Medians per cluster ===
# cluster_hdb100             0        1        2        3
# equivalent_diameter    5.528    7.736    5.293   17.150
# roundness              0.734    0.385    1.025    0.139
# aspect_ratio           3.307    3.373    1.634    1.314
# solidity               0.579    0.437    0.841    0.491
# feret_ratio            0.325    0.333    0.596    0.851
# mean_intensity       143.889  142.500  134.966   61.323
# std_intensity          3.456    4.625    4.762   23.815
# glcm_correlation       0.876    0.900    0.710    0.944
# lbp_mean             107.956  117.026  100.000  124.554
#
# === Std per cluster ===
# cluster_hdb100            0       1       2       3
# equivalent_diameter   1.097   3.585   2.194   0.105
# roundness             0.183   0.202   0.310   0.042
# aspect_ratio          0.332   0.473   0.609   0.192
# solidity              0.049   0.068   0.120   0.071
# feret_ratio           0.038   0.059   0.150   0.107
# mean_intensity       11.771  16.125  25.223  28.157
# std_intensity         1.233   2.450   7.850   6.892
# glcm_correlation      0.086   0.072   0.204   0.045
# lbp_mean              8.823  10.027  17.040   4.881

# %%
sil  = silhouette_score(X_scaled[mask_100], labels_100[mask_100],
                        sample_size=10000, random_state=42)
db   = davies_bouldin_score(X_scaled[mask_100], labels_100[mask_100])
ch   = calinski_harabasz_score(X_scaled[mask_100], labels_100[mask_100])
print(f"Silhouette:      {sil:.4f}")
print(f"Davies-Bouldin:  {db:.4f}")
print(f"Calinski-Harabasz: {ch:.1f}")
# Out:
# Silhouette:      0.4945
# Davies-Bouldin:  0.8288
# Calinski-Harabasz: 3851.7

# %%
# ── Estrategia 1: bajar min_cluster_size para forzar más clusters ──
for min_size in [50, 75, 100, 150]:
    for min_s in [3, 5, 10]:
        hdb = HDBSCAN(min_cluster_size=min_size, min_samples=min_s,
                      cluster_selection_method='eom')
        labels = hdb.fit_predict(X_scaled)
        mask = labels != -1
        n = len(set(labels[mask]))
        noise = (labels == -1).mean() * 100
        if 3 <= n <= 7:  # solo mostrar si encuentra entre 3 y 7 clusters
            sil = silhouette_score(X_scaled[mask], labels[mask],
                                   sample_size=10000, random_state=42)
            db  = davies_bouldin_score(X_scaled[mask], labels[mask])
            print(f"min_size={min_size} min_samples={min_s}: "
                  f"k={n} sil={sil:.4f} db={db:.4f} noise={noise:.1f}%")

# ── Estrategia 2: sub-clustering solo del cluster 1 ───────────────
print("\n=== Sub-clustering del cluster 1 (148k partículas) ===")
mask_c1 = labels_100 == 1
X_c1 = X_scaled[mask_c1]

# HDBSCAN dentro del cluster 1
for min_size in [100, 200, 500, 1000]:
    hdb_sub = HDBSCAN(min_cluster_size=min_size, min_samples=10,
                      cluster_selection_method='eom')
    labels_sub = hdb_sub.fit_predict(X_c1)
    mask_sub = labels_sub != -1
    n_sub = len(set(labels_sub[mask_sub]))
    noise_sub = (labels_sub == -1).mean() * 100
    if n_sub > 1:
        sil_sub = silhouette_score(X_c1[mask_sub], labels_sub[mask_sub],
                                   sample_size=10000, random_state=42)
        print(f"  min_size={min_size}: k={n_sub} sil={sil_sub:.4f} noise={noise_sub:.1f}%")
    else:
        print(f"  min_size={min_size}: k={n_sub} — no split")
# Out:
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(
# c:\Users\Usuario\anaconda3\envs\nlp\Lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py:722: FutureWarning: The default value of `copy` will change from False to True in 1.10. Explicitly set a value for `copy` to silence this warning.
#   warn(

# %%
# Perfil de HDBSCAN min_size=50, min_samples=10, k=5
hdb_5 = HDBSCAN(min_cluster_size=50, min_samples=10,
                cluster_selection_method='eom')
labels_5 = hdb_5.fit_predict(X_scaled)

mask_5 = labels_5 != -1
print(f"Clusters: {len(set(labels_5[mask_5]))}")
print(f"Noise: {(labels_5==-1).mean()*100:.1f}%")

print(f"\nCluster sizes:")
print(pd.Series(labels_5).value_counts().sort_index())

df_clean['cluster_hdb5'] = labels_5
df_hdb5 = df_clean[mask_5].copy()

cols_show = ['equivalent_diameter', 'roundness', 'aspect_ratio',
             'solidity', 'feret_ratio', 'mean_intensity',
             'std_intensity', 'glcm_correlation', 'lbp_mean']

print("\n=== Medians per cluster ===")
print(df_hdb5.groupby('cluster_hdb5')[cols_show].median().round(3).T.to_string())

print("\n=== Std per cluster ===")
print(df_hdb5.groupby('cluster_hdb5')[cols_show].std().round(3).T.to_string())
